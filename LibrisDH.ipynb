# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/emmbu07/DHLiUB/blob/master/LibrisDH.ipynb)

# %%
import requests
import json
r = requests.get("http://libris.kb.se/xsearch?query=TIT:(digital*+humani*)&format=json&n=200")
data = json.loads(r.content)

list = data['xsearch']['list']

# %%
for book in list:
  print(book.get('title'))
  print(book.get('creator'))
  print(book.get('date'))
  
  print("--------------------------------------")
# Out:
# Digital Humanities Quarterly [Elektronisk resurs]
# None
# None
# --------------------------------------
# Digital_humanities
# Schnapp, Jeffrey (harvard University)
# None
# --------------------------------------
# Digital humanities : knowledge and critique in a digital age
# Berry, David M.
# None
# --------------------------------------
# Digital humanities : knowledge and critique in a digital age
# Berry, David M.
# None
# --------------------------------------
# Digital humanitarians : how big data is changing the face of humanitarian response
# Meier, Patrick,
# None
# --------------------------------------
# The big humanities : digital humanities/digital laboratories
# Lane, Richard J.
# None
# --------------------------------------
# Interdisciplining digital humanities [Elektronisk resurs] : boundary work in an emerging field
# Klein, Julie Thompson
# 2014
# --------------------------------------
# ...
